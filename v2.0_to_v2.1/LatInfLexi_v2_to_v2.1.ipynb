# %%
import pandas as pd
import re

# %% [markdown]
# # Getting files from previous version

# %%
# %%bash
# cd ../
# git checkout v2.0.0 -- LatInfLexi-forms.csv
# git checkout v2.0.0 -- LatInfLexi-lexemes.csv
# git checkout v2.0.0 -- LatInfLexi-cells.csv

# %% [markdown]
# # Reading files

# %%
LatInfLexi_forms = pd.read_csv("../LatInfLexi-forms.csv", index_col="form_id")
LatInfLexi_cells = pd.read_csv("../LatInfLexi-cells.csv", index_col="cell_id")
LatInfLexi_lexemes = pd.read_csv("../LatInfLexi-lexemes.csv", index_col="lexeme_id")

# %% [markdown]
# # Changes to forms

# %%
changes_forms = {'form_766318_v': {'orth_form': 'stringō',
  'phon_form': 's t r ˈi n ɡ oː',
  'frequency': 11,
  'frequency_Antiquitas': 0,
  'frequency_AetasPatrum': 4,
  'frequency_MediumAeuum': 7,
  'frequency_RecentiorLatinitas': 0},
 'form_766319_v': {'orth_form': 'stringis',
  'phon_form': 's t r ˈi n ɡ i s',
  'frequency': 13,
  'frequency_Antiquitas': 3,
  'frequency_AetasPatrum': 4,
  'frequency_MediumAeuum': 6,
  'frequency_RecentiorLatinitas': 0},
 'form_766320_v': {'orth_form': 'stringit',
  'phon_form': 's t r ˈi n ɡ i t',
  'frequency': 192,
  'frequency_Antiquitas': 25,
  'frequency_AetasPatrum': 63,
  'frequency_MediumAeuum': 99,
  'frequency_RecentiorLatinitas': 5},
 'form_766321_v': {'orth_form': 'stringimus',
  'phon_form': 's t r ˈi n ɡ i m u s',
  'frequency': 6,
  'frequency_Antiquitas': 1,
  'frequency_AetasPatrum': 3,
  'frequency_MediumAeuum': 2,
  'frequency_RecentiorLatinitas': 0},
 'form_766322_v': {'orth_form': 'stringitis',
  'phon_form': 's t r ˈi n ɡ i t i s',
  'frequency': 3,
  'frequency_Antiquitas': 0,
  'frequency_AetasPatrum': 3,
  'frequency_MediumAeuum': 0,
  'frequency_RecentiorLatinitas': 0},
 'form_766323_v': {'orth_form': 'stringunt',
  'phon_form': 's t r ˈi n ɡ u n t',
  'frequency': 48,
  'frequency_Antiquitas': 9,
  'frequency_AetasPatrum': 14,
  'frequency_MediumAeuum': 24,
  'frequency_RecentiorLatinitas': 1},
 'form_766324_v': {'orth_form': 'stringēbam',
  'phon_form': 's t r i n ɡ ˈeː b a m',
  'frequency': 1,
  'frequency_Antiquitas': 0,
  'frequency_AetasPatrum': 1,
  'frequency_MediumAeuum': 0,
  'frequency_RecentiorLatinitas': 0},
 'form_766325_v': {'orth_form': 'stringēbās',
  'phon_form': 's t r i n ɡ ˈeː b aː s',
  'frequency': 0,
  'frequency_Antiquitas': 0,
  'frequency_AetasPatrum': 0,
  'frequency_MediumAeuum': 0,
  'frequency_RecentiorLatinitas': 0},
 'form_766326_v': {'orth_form': 'stringēbat',
  'phon_form': 's t r i n ɡ ˈeː b a t',
  'frequency': 21,
  'frequency_Antiquitas': 5,
  'frequency_AetasPatrum': 6,
  'frequency_MediumAeuum': 10,
  'frequency_RecentiorLatinitas': 0},
 'form_766327_v': {'orth_form': 'stringēbāmus',
  'phon_form': 's t r i n ɡ eː b ˈaː m u s',
  'frequency': 0,
  'frequency_Antiquitas': 0,
  'frequency_AetasPatrum': 0,
  'frequency_MediumAeuum': 0,
  'frequency_RecentiorLatinitas': 0},
 'form_766328_v': {'orth_form': 'stringēbātis',
  'phon_form': 's t r i n ɡ eː b ˈaː t i s',
  'frequency': 0,
  'frequency_Antiquitas': 0,
  'frequency_AetasPatrum': 0,
  'frequency_MediumAeuum': 0,
  'frequency_RecentiorLatinitas': 0},
 'form_766329_v': {'orth_form': 'stringēbant',
  'phon_form': 's t r i n ɡ ˈeː b a n t',
  'frequency': 5,
  'frequency_Antiquitas': 2,
  'frequency_AetasPatrum': 2,
  'frequency_MediumAeuum': 1,
  'frequency_RecentiorLatinitas': 0},
 'form_766330_v': {'orth_form': 'stringam',
  'phon_form': 's t r ˈi n ɡ a m',
  'frequency': 7,
  'frequency_Antiquitas': 3,
  'frequency_AetasPatrum': 2,
  'frequency_MediumAeuum': 2,
  'frequency_RecentiorLatinitas': 0},
 'form_766331_v': {'orth_form': 'stringēs',
  'phon_form': 's t r ˈi n ɡ eː s',
  'frequency': 5,
  'frequency_Antiquitas': 0,
  'frequency_AetasPatrum': 3,
  'frequency_MediumAeuum': 2,
  'frequency_RecentiorLatinitas': 0},
 'form_766332_v': {'orth_form': 'stringet',
  'phon_form': 's t r ˈi n ɡ e t',
  'frequency': 10,
  'frequency_Antiquitas': 1,
  'frequency_AetasPatrum': 3,
  'frequency_MediumAeuum': 6,
  'frequency_RecentiorLatinitas': 0},
 'form_766333_v': {'orth_form': 'stringēmus',
  'phon_form': 's t r i n ɡ ˈeː m u s',
  'frequency': 0,
  'frequency_Antiquitas': 0,
  'frequency_AetasPatrum': 0,
  'frequency_MediumAeuum': 0,
  'frequency_RecentiorLatinitas': 0},
 'form_766334_v': {'orth_form': 'stringētis',
  'phon_form': 's t r i n ɡ ˈeː t i s',
  'frequency': 0,
  'frequency_Antiquitas': 0,
  'frequency_AetasPatrum': 0,
  'frequency_MediumAeuum': 0,
  'frequency_RecentiorLatinitas': 0},
 'form_766335_v': {'orth_form': 'stringent',
  'phon_form': 's t r ˈi n ɡ e n t',
  'frequency': 1,
  'frequency_Antiquitas': 0,
  'frequency_AetasPatrum': 0,
  'frequency_MediumAeuum': 1,
  'frequency_RecentiorLatinitas': 0},
 'form_766336_v': {'orth_form': 'stringam',
  'phon_form': 's t r ˈi n ɡ a m',
  'frequency': 7,
  'frequency_Antiquitas': 3,
  'frequency_AetasPatrum': 2,
  'frequency_MediumAeuum': 2,
  'frequency_RecentiorLatinitas': 0},
 'form_766337_v': {'orth_form': 'stringās',
  'phon_form': 's t r ˈi n ɡ aː s',
  'frequency': 3,
  'frequency_Antiquitas': 0,
  'frequency_AetasPatrum': 0,
  'frequency_MediumAeuum': 3,
  'frequency_RecentiorLatinitas': 0},
 'form_766338_v': {'orth_form': 'stringat',
  'phon_form': 's t r ˈi n ɡ a t',
  'frequency': 38,
  'frequency_Antiquitas': 6,
  'frequency_AetasPatrum': 11,
  'frequency_MediumAeuum': 15,
  'frequency_RecentiorLatinitas': 6},
 'form_766339_v': {'orth_form': 'stringāmus',
  'phon_form': 's t r i n ɡ ˈaː m u s',
  'frequency': 3,
  'frequency_Antiquitas': 0,
  'frequency_AetasPatrum': 2,
  'frequency_MediumAeuum': 1,
  'frequency_RecentiorLatinitas': 0},
 'form_766340_v': {'orth_form': 'stringātis',
  'phon_form': 's t r i n ɡ ˈaː t i s',
  'frequency': 0,
  'frequency_Antiquitas': 0,
  'frequency_AetasPatrum': 0,
  'frequency_MediumAeuum': 0,
  'frequency_RecentiorLatinitas': 0},
 'form_766341_v': {'orth_form': 'stringant',
  'phon_form': 's t r ˈi n ɡ a n t',
  'frequency': 13,
  'frequency_Antiquitas': 0,
  'frequency_AetasPatrum': 5,
  'frequency_MediumAeuum': 6,
  'frequency_RecentiorLatinitas': 2},
 'form_766342_v': {'orth_form': 'stringerem',
  'phon_form': 's t r ˈi n ɡ e r e m',
  'frequency': 3,
  'frequency_Antiquitas': 0,
  'frequency_AetasPatrum': 2,
  'frequency_MediumAeuum': 1,
  'frequency_RecentiorLatinitas': 0},
 'form_766343_v': {'orth_form': 'stringerēs',
  'phon_form': 's t r ˈi n ɡ e r eː s',
  'frequency': 0,
  'frequency_Antiquitas': 0,
  'frequency_AetasPatrum': 0,
  'frequency_MediumAeuum': 0,
  'frequency_RecentiorLatinitas': 0},
 'form_766344_v': {'orth_form': 'stringeret',
  'phon_form': 's t r ˈi n ɡ e r e t',
  'frequency': 15,
  'frequency_Antiquitas': 3,
  'frequency_AetasPatrum': 6,
  'frequency_MediumAeuum': 6,
  'frequency_RecentiorLatinitas': 0},
 'form_766345_v': {'orth_form': 'stringerēmus',
  'phon_form': 's t r i n ɡ e r ˈeː m u s',
  'frequency': 0,
  'frequency_Antiquitas': 0,
  'frequency_AetasPatrum': 0,
  'frequency_MediumAeuum': 0,
  'frequency_RecentiorLatinitas': 0},
 'form_766346_v': {'orth_form': 'stringerētis',
  'phon_form': 's t r i n ɡ e r ˈeː t i s',
  'frequency': 1,
  'frequency_Antiquitas': 0,
  'frequency_AetasPatrum': 0,
  'frequency_MediumAeuum': 1,
  'frequency_RecentiorLatinitas': 0},
 'form_766347_v': {'orth_form': 'stringerent',
  'phon_form': 's t r ˈi n ɡ e r e n t',
  'frequency': 6,
  'frequency_Antiquitas': 3,
  'frequency_AetasPatrum': 2,
  'frequency_MediumAeuum': 1,
  'frequency_RecentiorLatinitas': 0},
 'form_766348_v': {'orth_form': 'stringe',
  'phon_form': 's t r ˈi n ɡ e',
  'frequency': 20,
  'frequency_Antiquitas': 4,
  'frequency_AetasPatrum': 7,
  'frequency_MediumAeuum': 9,
  'frequency_RecentiorLatinitas': 0},
 'form_766349_v': {'orth_form': 'stringite',
  'phon_form': 's t r ˈi n ɡ i t e',
  'frequency': 3,
  'frequency_Antiquitas': 1,
  'frequency_AetasPatrum': 2,
  'frequency_MediumAeuum': 0,
  'frequency_RecentiorLatinitas': 0},
 'form_766350_v': {'orth_form': 'stringitō',
  'phon_form': 's t r ˈi n ɡ i t oː',
  'frequency': 5,
  'frequency_Antiquitas': 5,
  'frequency_AetasPatrum': 0,
  'frequency_MediumAeuum': 0,
  'frequency_RecentiorLatinitas': 0},
 'form_766351_v': {'orth_form': 'stringitō',
  'phon_form': 's t r ˈi n ɡ i t oː',
  'frequency': 5,
  'frequency_Antiquitas': 5,
  'frequency_AetasPatrum': 0,
  'frequency_MediumAeuum': 0,
  'frequency_RecentiorLatinitas': 0},
 'form_766352_v': {'orth_form': 'stringitōte',
  'phon_form': 's t r i n ɡ i t ˈoː t e',
  'frequency': 0,
  'frequency_Antiquitas': 0,
  'frequency_AetasPatrum': 0,
  'frequency_MediumAeuum': 0,
  'frequency_RecentiorLatinitas': 0},
 'form_766353_v': {'orth_form': 'stringuntō',
  'phon_form': 's t r i n ɡ ˈu n t oː',
  'frequency': 0,
  'frequency_Antiquitas': 0,
  'frequency_AetasPatrum': 0,
  'frequency_MediumAeuum': 0,
  'frequency_RecentiorLatinitas': 0},
 'form_766354_v': {'orth_form': 'stringere',
  'phon_form': 's t r ˈi n ɡ e r e',
  'frequency': 86,
  'frequency_Antiquitas': 22,
  'frequency_AetasPatrum': 34,
  'frequency_MediumAeuum': 30,
  'frequency_RecentiorLatinitas': 0},
 'form_766355_v': {'orth_form': 'stringor',
  'phon_form': 's t r ˈi n ɡ o r',
  'frequency': 1,
  'frequency_Antiquitas': 1,
  'frequency_AetasPatrum': 0,
  'frequency_MediumAeuum': 0,
  'frequency_RecentiorLatinitas': 0},
 'form_766356_v': {'orth_form': 'stringeris',
  'phon_form': 's t r ˈi n ɡ e r i s',
  'frequency': 8,
  'frequency_Antiquitas': 1,
  'frequency_AetasPatrum': 2,
  'frequency_MediumAeuum': 5,
  'frequency_RecentiorLatinitas': 0},
 'form_766357_v': {'orth_form': 'stringitur',
  'phon_form': 's t r ˈi n ɡ i t u r',
  'frequency': 126,
  'frequency_Antiquitas': 7,
  'frequency_AetasPatrum': 56,
  'frequency_MediumAeuum': 58,
  'frequency_RecentiorLatinitas': 5},
 'form_766358_v': {'orth_form': 'stringimur',
  'phon_form': 's t r ˈi n ɡ i m u r',
  'frequency': 2,
  'frequency_Antiquitas': 0,
  'frequency_AetasPatrum': 1,
  'frequency_MediumAeuum': 1,
  'frequency_RecentiorLatinitas': 0},
 'form_766359_v': {'orth_form': 'stringiminī',
  'phon_form': 's t r i n ɡ ˈi m i n iː',
  'frequency': 0,
  'frequency_Antiquitas': 0,
  'frequency_AetasPatrum': 0,
  'frequency_MediumAeuum': 0,
  'frequency_RecentiorLatinitas': 0},
 'form_766360_v': {'orth_form': 'stringuntur',
  'phon_form': 's t r i n ɡ ˈu n t u r',
  'frequency': 26,
  'frequency_Antiquitas': 2,
  'frequency_AetasPatrum': 8,
  'frequency_MediumAeuum': 13,
  'frequency_RecentiorLatinitas': 3},
 'form_766361_v': {'orth_form': 'stringēbar',
  'phon_form': 's t r i n ɡ ˈeː b a r',
  'frequency': 0,
  'frequency_Antiquitas': 0,
  'frequency_AetasPatrum': 0,
  'frequency_MediumAeuum': 0,
  'frequency_RecentiorLatinitas': 0},
 'form_766362_v': {'orth_form': 'stringēbāris',
  'phon_form': 's t r i n ɡ eː b ˈaː r i s',
  'frequency': 0,
  'frequency_Antiquitas': 0,
  'frequency_AetasPatrum': 0,
  'frequency_MediumAeuum': 0,
  'frequency_RecentiorLatinitas': 0},
 'form_766363_v': {'orth_form': 'stringēbātur',
  'phon_form': 's t r i n ɡ eː b ˈaː t u r',
  'frequency': 16,
  'frequency_Antiquitas': 0,
  'frequency_AetasPatrum': 8,
  'frequency_MediumAeuum': 8,
  'frequency_RecentiorLatinitas': 0},
 'form_766364_v': {'orth_form': 'stringēbāmur',
  'phon_form': 's t r i n ɡ eː b ˈaː m u r',
  'frequency': 1,
  'frequency_Antiquitas': 0,
  'frequency_AetasPatrum': 1,
  'frequency_MediumAeuum': 0,
  'frequency_RecentiorLatinitas': 0},
 'form_766365_v': {'orth_form': 'stringēbāminī',
  'phon_form': 's t r i n ɡ eː b ˈaː m i n iː',
  'frequency': 0,
  'frequency_Antiquitas': 0,
  'frequency_AetasPatrum': 0,
  'frequency_MediumAeuum': 0,
  'frequency_RecentiorLatinitas': 0},
 'form_766366_v': {'orth_form': 'stringēbantur',
  'phon_form': 's t r i n ɡ eː b ˈa n t u r',
  'frequency': 9,
  'frequency_Antiquitas': 0,
  'frequency_AetasPatrum': 6,
  'frequency_MediumAeuum': 3,
  'frequency_RecentiorLatinitas': 0},
 'form_766367_v': {'orth_form': 'stringar',
  'phon_form': 's t r ˈi n ɡ a r',
  'frequency': 0,
  'frequency_Antiquitas': 0,
  'frequency_AetasPatrum': 0,
  'frequency_MediumAeuum': 0,
  'frequency_RecentiorLatinitas': 0},
 'form_766368_v': {'orth_form': 'stringēris',
  'phon_form': 's t r i n ɡ ˈeː r i s',
  'frequency': 8,
  'frequency_Antiquitas': 1,
  'frequency_AetasPatrum': 2,
  'frequency_MediumAeuum': 5,
  'frequency_RecentiorLatinitas': 0},
 'form_766369_v': {'orth_form': 'stringētur',
  'phon_form': 's t r i n ɡ ˈeː t u r',
  'frequency': 12,
  'frequency_Antiquitas': 0,
  'frequency_AetasPatrum': 7,
  'frequency_MediumAeuum': 5,
  'frequency_RecentiorLatinitas': 0},
 'form_766370_v': {'orth_form': 'stringēmur',
  'phon_form': 's t r i n ɡ ˈeː m u r',
  'frequency': 0,
  'frequency_Antiquitas': 0,
  'frequency_AetasPatrum': 0,
  'frequency_MediumAeuum': 0,
  'frequency_RecentiorLatinitas': 0},
 'form_766371_v': {'orth_form': 'stringēminī',
  'phon_form': 's t r i n ɡ ˈeː m i n iː',
  'frequency': 0,
  'frequency_Antiquitas': 0,
  'frequency_AetasPatrum': 0,
  'frequency_MediumAeuum': 0,
  'frequency_RecentiorLatinitas': 0},
 'form_766372_v': {'orth_form': 'stringentur',
  'phon_form': 's t r i n ɡ ˈe n t u r',
  'frequency': 1,
  'frequency_Antiquitas': 1,
  'frequency_AetasPatrum': 0,
  'frequency_MediumAeuum': 0,
  'frequency_RecentiorLatinitas': 0},
 'form_766373_v': {'orth_form': 'stringar',
  'phon_form': 's t r ˈi n ɡ a r',
  'frequency': 0,
  'frequency_Antiquitas': 0,
  'frequency_AetasPatrum': 0,
  'frequency_MediumAeuum': 0,
  'frequency_RecentiorLatinitas': 0},
 'form_766374_v': {'orth_form': 'stringāris',
  'phon_form': 's t r i n ɡ ˈaː r i s',
  'frequency': 8,
  'frequency_Antiquitas': 1,
  'frequency_AetasPatrum': 2,
  'frequency_MediumAeuum': 5,
  'frequency_RecentiorLatinitas': 0},
 'form_766375_v': {'orth_form': 'stringātur',
  'phon_form': 's t r i n ɡ ˈaː t u r',
  'frequency': 14,
  'frequency_Antiquitas': 3,
  'frequency_AetasPatrum': 6,
  'frequency_MediumAeuum': 5,
  'frequency_RecentiorLatinitas': 0},
 'form_766376_v': {'orth_form': 'stringāmur',
  'phon_form': 's t r i n ɡ ˈaː m u r',
  'frequency': 3,
  'frequency_Antiquitas': 0,
  'frequency_AetasPatrum': 2,
  'frequency_MediumAeuum': 1,
  'frequency_RecentiorLatinitas': 0},
 'form_766377_v': {'orth_form': 'stringāminī',
  'phon_form': 's t r i n ɡ ˈaː m i n iː',
  'frequency': 0,
  'frequency_Antiquitas': 0,
  'frequency_AetasPatrum': 0,
  'frequency_MediumAeuum': 0,
  'frequency_RecentiorLatinitas': 0},
 'form_766378_v': {'orth_form': 'stringantur',
  'phon_form': 's t r i n ɡ ˈa n t u r',
  'frequency': 8,
  'frequency_Antiquitas': 3,
  'frequency_AetasPatrum': 3,
  'frequency_MediumAeuum': 2,
  'frequency_RecentiorLatinitas': 0},
 'form_766379_v': {'orth_form': 'stringerer',
  'phon_form': 's t r ˈi n ɡ e r e r',
  'frequency': 0,
  'frequency_Antiquitas': 0,
  'frequency_AetasPatrum': 0,
  'frequency_MediumAeuum': 0,
  'frequency_RecentiorLatinitas': 0},
 'form_766380_v': {'orth_form': 'stringerēris',
  'phon_form': 's t r i n ɡ e r ˈeː r i s',
  'frequency': 0,
  'frequency_Antiquitas': 0,
  'frequency_AetasPatrum': 0,
  'frequency_MediumAeuum': 0,
  'frequency_RecentiorLatinitas': 0},
 'form_766381_v': {'orth_form': 'stringerētur',
  'phon_form': 's t r i n ɡ e r ˈeː t u r',
  'frequency': 16,
  'frequency_Antiquitas': 0,
  'frequency_AetasPatrum': 9,
  'frequency_MediumAeuum': 7,
  'frequency_RecentiorLatinitas': 0},
 'form_766382_v': {'orth_form': 'stringerēmur',
  'phon_form': 's t r i n ɡ e r ˈeː m u r',
  'frequency': 0,
  'frequency_Antiquitas': 0,
  'frequency_AetasPatrum': 0,
  'frequency_MediumAeuum': 0,
  'frequency_RecentiorLatinitas': 0},
 'form_766383_v': {'orth_form': 'stringerēminī',
  'phon_form': 's t r i n ɡ e r ˈeː m i n iː',
  'frequency': 0,
  'frequency_Antiquitas': 0,
  'frequency_AetasPatrum': 0,
  'frequency_MediumAeuum': 0,
  'frequency_RecentiorLatinitas': 0},
 'form_766384_v': {'orth_form': 'stringerentur',
  'phon_form': 's t r i n ɡ e r ˈe n t u r',
  'frequency': 4,
  'frequency_Antiquitas': 0,
  'frequency_AetasPatrum': 2,
  'frequency_MediumAeuum': 2,
  'frequency_RecentiorLatinitas': 0},
 'form_766385_v': {'orth_form': 'stringere',
  'phon_form': 's t r ˈi n ɡ e r e',
  'frequency': 86,
  'frequency_Antiquitas': 22,
  'frequency_AetasPatrum': 34,
  'frequency_MediumAeuum': 30,
  'frequency_RecentiorLatinitas': 0},
 'form_766386_v': {'orth_form': 'stringiminī',
  'phon_form': 's t r i n ɡ ˈi m i n iː',
  'frequency': 0,
  'frequency_Antiquitas': 0,
  'frequency_AetasPatrum': 0,
  'frequency_MediumAeuum': 0,
  'frequency_RecentiorLatinitas': 0},
 'form_766387_v': {'orth_form': 'stringitor',
  'phon_form': 's t r ˈi n ɡ i t o r',
  'frequency': 0,
  'frequency_Antiquitas': 0,
  'frequency_AetasPatrum': 0,
  'frequency_MediumAeuum': 0,
  'frequency_RecentiorLatinitas': 0},
 'form_766388_v': {'orth_form': 'stringitor',
  'phon_form': 's t r ˈi n ɡ i t o r',
  'frequency': 0,
  'frequency_Antiquitas': 0,
  'frequency_AetasPatrum': 0,
  'frequency_MediumAeuum': 0,
  'frequency_RecentiorLatinitas': 0},
 'form_766389_v': {'orth_form': 'stringuntor',
  'phon_form': 's t r i n ɡ ˈu n t o r',
  'frequency': 0,
  'frequency_Antiquitas': 0,
  'frequency_AetasPatrum': 0,
  'frequency_MediumAeuum': 0,
  'frequency_RecentiorLatinitas': 0},
 'form_766390_v': {'orth_form': 'stringī',
  'phon_form': 's t r ˈi n ɡ iː',
  'frequency': 22,
  'frequency_Antiquitas': 4,
  'frequency_AetasPatrum': 9,
  'frequency_MediumAeuum': 9,
  'frequency_RecentiorLatinitas': 0},
 'form_766391_v': {'orth_form': 'stringendī',
  'phon_form': 's t r i n ɡ ˈe n d iː',
  'frequency': 2,
  'frequency_Antiquitas': 1,
  'frequency_AetasPatrum': 0,
  'frequency_MediumAeuum': 1,
  'frequency_RecentiorLatinitas': 0},
 'form_766392_v': {'orth_form': 'stringendō',
  'phon_form': 's t r i n ɡ ˈe n d oː',
  'frequency': 12,
  'frequency_Antiquitas': 1,
  'frequency_AetasPatrum': 6,
  'frequency_MediumAeuum': 5,
  'frequency_RecentiorLatinitas': 0},
 'form_766393_v': {'orth_form': 'stringendum',
  'phon_form': 's t r i n ɡ ˈe n d u m',
  'frequency': 4,
  'frequency_Antiquitas': 0,
  'frequency_AetasPatrum': 3,
  'frequency_MediumAeuum': 1,
  'frequency_RecentiorLatinitas': 0},
 'form_766394_v': {'orth_form': 'stringendō',
  'phon_form': 's t r i n ɡ ˈe n d oː',
  'frequency': 12,
  'frequency_Antiquitas': 1,
  'frequency_AetasPatrum': 6,
  'frequency_MediumAeuum': 5,
  'frequency_RecentiorLatinitas': 0},
 'form_766395_v': {'orth_form': 'stringendus',
  'phon_form': 's t r i n ɡ ˈe n d u s',
  'frequency': 6,
  'frequency_Antiquitas': 2,
  'frequency_AetasPatrum': 3,
  'frequency_MediumAeuum': 1,
  'frequency_RecentiorLatinitas': 0},
 'form_766396_v': {'orth_form': 'stringenda',
  'phon_form': 's t r i n ɡ ˈe n d a',
  'frequency': 2,
  'frequency_Antiquitas': 1,
  'frequency_AetasPatrum': 1,
  'frequency_MediumAeuum': 0,
  'frequency_RecentiorLatinitas': 0},
 'form_766397_v': {'orth_form': 'stringendum',
  'phon_form': 's t r i n ɡ ˈe n d u m',
  'frequency': 4,
  'frequency_Antiquitas': 0,
  'frequency_AetasPatrum': 3,
  'frequency_MediumAeuum': 1,
  'frequency_RecentiorLatinitas': 0},
 'form_766398_v': {'orth_form': 'stringendī',
  'phon_form': 's t r i n ɡ ˈe n d iː',
  'frequency': 2,
  'frequency_Antiquitas': 1,
  'frequency_AetasPatrum': 0,
  'frequency_MediumAeuum': 1,
  'frequency_RecentiorLatinitas': 0},
 'form_766399_v': {'orth_form': 'stringendae',
  'phon_form': 's t r i n ɡ ˈe n d a j',
  'frequency': 1,
  'frequency_Antiquitas': 1,
  'frequency_AetasPatrum': 0,
  'frequency_MediumAeuum': 0,
  'frequency_RecentiorLatinitas': 0},
 'form_766400_v': {'orth_form': 'stringendī',
  'phon_form': 's t r i n ɡ ˈe n d iː',
  'frequency': 2,
  'frequency_Antiquitas': 1,
  'frequency_AetasPatrum': 0,
  'frequency_MediumAeuum': 1,
  'frequency_RecentiorLatinitas': 0},
 'form_766401_v': {'orth_form': 'stringendō',
  'phon_form': 's t r i n ɡ ˈe n d oː',
  'frequency': 12,
  'frequency_Antiquitas': 1,
  'frequency_AetasPatrum': 6,
  'frequency_MediumAeuum': 5,
  'frequency_RecentiorLatinitas': 0},
 'form_766402_v': {'orth_form': 'stringendae',
  'phon_form': 's t r i n ɡ ˈe n d a j',
  'frequency': 1,
  'frequency_Antiquitas': 1,
  'frequency_AetasPatrum': 0,
  'frequency_MediumAeuum': 0,
  'frequency_RecentiorLatinitas': 0},
 'form_766403_v': {'orth_form': 'stringendō',
  'phon_form': 's t r i n ɡ ˈe n d oː',
  'frequency': 12,
  'frequency_Antiquitas': 1,
  'frequency_AetasPatrum': 6,
  'frequency_MediumAeuum': 5,
  'frequency_RecentiorLatinitas': 0},
 'form_766404_v': {'orth_form': 'stringendum',
  'phon_form': 's t r i n ɡ ˈe n d u m',
  'frequency': 4,
  'frequency_Antiquitas': 0,
  'frequency_AetasPatrum': 3,
  'frequency_MediumAeuum': 1,
  'frequency_RecentiorLatinitas': 0},
 'form_766405_v': {'orth_form': 'stringendam',
  'phon_form': 's t r i n ɡ ˈe n d a m',
  'frequency': 0,
  'frequency_Antiquitas': 0,
  'frequency_AetasPatrum': 0,
  'frequency_MediumAeuum': 0,
  'frequency_RecentiorLatinitas': 0},
 'form_766406_v': {'orth_form': 'stringendum',
  'phon_form': 's t r i n ɡ ˈe n d u m',
  'frequency': 4,
  'frequency_Antiquitas': 0,
  'frequency_AetasPatrum': 3,
  'frequency_MediumAeuum': 1,
  'frequency_RecentiorLatinitas': 0},
 'form_766407_v': {'orth_form': 'stringende',
  'phon_form': 's t r i n ɡ ˈe n d e',
  'frequency': 0,
  'frequency_Antiquitas': 0,
  'frequency_AetasPatrum': 0,
  'frequency_MediumAeuum': 0,
  'frequency_RecentiorLatinitas': 0},
 'form_766408_v': {'orth_form': 'stringenda',
  'phon_form': 's t r i n ɡ ˈe n d a',
  'frequency': 2,
  'frequency_Antiquitas': 1,
  'frequency_AetasPatrum': 1,
  'frequency_MediumAeuum': 0,
  'frequency_RecentiorLatinitas': 0},
 'form_766409_v': {'orth_form': 'stringendum',
  'phon_form': 's t r i n ɡ ˈe n d u m',
  'frequency': 4,
  'frequency_Antiquitas': 0,
  'frequency_AetasPatrum': 3,
  'frequency_MediumAeuum': 1,
  'frequency_RecentiorLatinitas': 0},
 'form_766410_v': {'orth_form': 'stringendō',
  'phon_form': 's t r i n ɡ ˈe n d oː',
  'frequency': 12,
  'frequency_Antiquitas': 1,
  'frequency_AetasPatrum': 6,
  'frequency_MediumAeuum': 5,
  'frequency_RecentiorLatinitas': 0},
 'form_766411_v': {'orth_form': 'stringendā',
  'phon_form': 's t r i n ɡ ˈe n d aː',
  'frequency': 2,
  'frequency_Antiquitas': 1,
  'frequency_AetasPatrum': 1,
  'frequency_MediumAeuum': 0,
  'frequency_RecentiorLatinitas': 0},
 'form_766412_v': {'orth_form': 'stringendō',
  'phon_form': 's t r i n ɡ ˈe n d oː',
  'frequency': 12,
  'frequency_Antiquitas': 1,
  'frequency_AetasPatrum': 6,
  'frequency_MediumAeuum': 5,
  'frequency_RecentiorLatinitas': 0},
 'form_766413_v': {'orth_form': 'stringendī',
  'phon_form': 's t r i n ɡ ˈe n d iː',
  'frequency': 2,
  'frequency_Antiquitas': 1,
  'frequency_AetasPatrum': 0,
  'frequency_MediumAeuum': 1,
  'frequency_RecentiorLatinitas': 0},
 'form_766414_v': {'orth_form': 'stringendae',
  'phon_form': 's t r i n ɡ ˈe n d a j',
  'frequency': 1,
  'frequency_Antiquitas': 1,
  'frequency_AetasPatrum': 0,
  'frequency_MediumAeuum': 0,
  'frequency_RecentiorLatinitas': 0},
 'form_766415_v': {'orth_form': 'stringenda',
  'phon_form': 's t r i n ɡ ˈe n d a',
  'frequency': 2,
  'frequency_Antiquitas': 1,
  'frequency_AetasPatrum': 1,
  'frequency_MediumAeuum': 0,
  'frequency_RecentiorLatinitas': 0},
 'form_766416_v': {'orth_form': 'stringendōrum',
  'phon_form': 's t r i n ɡ e n d ˈoː r u m',
  'frequency': 0,
  'frequency_Antiquitas': 0,
  'frequency_AetasPatrum': 0,
  'frequency_MediumAeuum': 0,
  'frequency_RecentiorLatinitas': 0},
 'form_766417_v': {'orth_form': 'stringendārum',
  'phon_form': 's t r i n ɡ e n d ˈaː r u m',
  'frequency': 0,
  'frequency_Antiquitas': 0,
  'frequency_AetasPatrum': 0,
  'frequency_MediumAeuum': 0,
  'frequency_RecentiorLatinitas': 0},
 'form_766418_v': {'orth_form': 'stringendōrum',
  'phon_form': 's t r i n ɡ e n d ˈoː r u m',
  'frequency': 0,
  'frequency_Antiquitas': 0,
  'frequency_AetasPatrum': 0,
  'frequency_MediumAeuum': 0,
  'frequency_RecentiorLatinitas': 0},
 'form_766419_v': {'orth_form': 'stringendīs',
  'phon_form': 's t r i n ɡ ˈe n d iː s',
  'frequency': 1,
  'frequency_Antiquitas': 1,
  'frequency_AetasPatrum': 0,
  'frequency_MediumAeuum': 0,
  'frequency_RecentiorLatinitas': 0},
 'form_766420_v': {'orth_form': 'stringendīs',
  'phon_form': 's t r i n ɡ ˈe n d iː s',
  'frequency': 1,
  'frequency_Antiquitas': 1,
  'frequency_AetasPatrum': 0,
  'frequency_MediumAeuum': 0,
  'frequency_RecentiorLatinitas': 0},
 'form_766421_v': {'orth_form': 'stringendīs',
  'phon_form': 's t r i n ɡ ˈe n d iː s',
  'frequency': 1,
  'frequency_Antiquitas': 1,
  'frequency_AetasPatrum': 0,
  'frequency_MediumAeuum': 0,
  'frequency_RecentiorLatinitas': 0},
 'form_766422_v': {'orth_form': 'stringendōs',
  'phon_form': 's t r i n ɡ ˈe n d oː s',
  'frequency': 1,
  'frequency_Antiquitas': 0,
  'frequency_AetasPatrum': 0,
  'frequency_MediumAeuum': 1,
  'frequency_RecentiorLatinitas': 0},
 'form_766423_v': {'orth_form': 'stringendās',
  'phon_form': 's t r i n ɡ ˈe n d aː s',
  'frequency': 0,
  'frequency_Antiquitas': 0,
  'frequency_AetasPatrum': 0,
  'frequency_MediumAeuum': 0,
  'frequency_RecentiorLatinitas': 0},
 'form_766424_v': {'orth_form': 'stringenda',
  'phon_form': 's t r i n ɡ ˈe n d a',
  'frequency': 2,
  'frequency_Antiquitas': 1,
  'frequency_AetasPatrum': 1,
  'frequency_MediumAeuum': 0,
  'frequency_RecentiorLatinitas': 0},
 'form_766425_v': {'orth_form': 'stringendī',
  'phon_form': 's t r i n ɡ ˈe n d iː',
  'frequency': 2,
  'frequency_Antiquitas': 1,
  'frequency_AetasPatrum': 0,
  'frequency_MediumAeuum': 1,
  'frequency_RecentiorLatinitas': 0},
 'form_766426_v': {'orth_form': 'stringendae',
  'phon_form': 's t r i n ɡ ˈe n d a j',
  'frequency': 1,
  'frequency_Antiquitas': 1,
  'frequency_AetasPatrum': 0,
  'frequency_MediumAeuum': 0,
  'frequency_RecentiorLatinitas': 0},
 'form_766427_v': {'orth_form': 'stringenda',
  'phon_form': 's t r i n ɡ ˈe n d a',
  'frequency': 2,
  'frequency_Antiquitas': 1,
  'frequency_AetasPatrum': 1,
  'frequency_MediumAeuum': 0,
  'frequency_RecentiorLatinitas': 0},
 'form_766428_v': {'orth_form': 'stringendīs',
  'phon_form': 's t r i n ɡ ˈe n d iː s',
  'frequency': 1,
  'frequency_Antiquitas': 1,
  'frequency_AetasPatrum': 0,
  'frequency_MediumAeuum': 0,
  'frequency_RecentiorLatinitas': 0},
 'form_766429_v': {'orth_form': 'stringendīs',
  'phon_form': 's t r i n ɡ ˈe n d iː s',
  'frequency': 1,
  'frequency_Antiquitas': 1,
  'frequency_AetasPatrum': 0,
  'frequency_MediumAeuum': 0,
  'frequency_RecentiorLatinitas': 0},
 'form_766430_v': {'orth_form': 'stringendīs',
  'phon_form': 's t r i n ɡ ˈe n d iː s',
  'frequency': 1,
  'frequency_Antiquitas': 1,
  'frequency_AetasPatrum': 0,
  'frequency_MediumAeuum': 0,
  'frequency_RecentiorLatinitas': 0},
 'form_766431_v': {'orth_form': 'stringēns',
  'phon_form': 's t r ˈi n ɡ eː n s',
  'frequency': 45,
  'frequency_Antiquitas': 2,
  'frequency_AetasPatrum': 14,
  'frequency_MediumAeuum': 26,
  'frequency_RecentiorLatinitas': 3},
 'form_766432_v': {'orth_form': 'stringēns',
  'phon_form': 's t r ˈi n ɡ eː n s',
  'frequency': 45,
  'frequency_Antiquitas': 2,
  'frequency_AetasPatrum': 14,
  'frequency_MediumAeuum': 26,
  'frequency_RecentiorLatinitas': 3},
 'form_766433_v': {'orth_form': 'stringēns',
  'phon_form': 's t r ˈi n ɡ eː n s',
  'frequency': 45,
  'frequency_Antiquitas': 2,
  'frequency_AetasPatrum': 14,
  'frequency_MediumAeuum': 26,
  'frequency_RecentiorLatinitas': 3},
 'form_766434_v': {'orth_form': 'stringentis',
  'phon_form': 's t r i n ɡ ˈe n t i s',
  'frequency': 1,
  'frequency_Antiquitas': 0,
  'frequency_AetasPatrum': 0,
  'frequency_MediumAeuum': 1,
  'frequency_RecentiorLatinitas': 0},
 'form_766435_v': {'orth_form': 'stringentis',
  'phon_form': 's t r i n ɡ ˈe n t i s',
  'frequency': 1,
  'frequency_Antiquitas': 0,
  'frequency_AetasPatrum': 0,
  'frequency_MediumAeuum': 1,
  'frequency_RecentiorLatinitas': 0},
 'form_766436_v': {'orth_form': 'stringentis',
  'phon_form': 's t r i n ɡ ˈe n t i s',
  'frequency': 1,
  'frequency_Antiquitas': 0,
  'frequency_AetasPatrum': 0,
  'frequency_MediumAeuum': 1,
  'frequency_RecentiorLatinitas': 0},
 'form_766437_v': {'orth_form': 'stringentī',
  'phon_form': 's t r i n ɡ ˈe n t iː',
  'frequency': 1,
  'frequency_Antiquitas': 0,
  'frequency_AetasPatrum': 1,
  'frequency_MediumAeuum': 0,
  'frequency_RecentiorLatinitas': 0},
 'form_766438_v': {'orth_form': 'stringentī',
  'phon_form': 's t r i n ɡ ˈe n t iː',
  'frequency': 1,
  'frequency_Antiquitas': 0,
  'frequency_AetasPatrum': 1,
  'frequency_MediumAeuum': 0,
  'frequency_RecentiorLatinitas': 0},
 'form_766439_v': {'orth_form': 'stringentī',
  'phon_form': 's t r i n ɡ ˈe n t iː',
  'frequency': 1,
  'frequency_Antiquitas': 0,
  'frequency_AetasPatrum': 1,
  'frequency_MediumAeuum': 0,
  'frequency_RecentiorLatinitas': 0},
 'form_766440_v': {'orth_form': 'stringentem',
  'phon_form': 's t r i n ɡ ˈe n t e m',
  'frequency': 6,
  'frequency_Antiquitas': 2,
  'frequency_AetasPatrum': 3,
  'frequency_MediumAeuum': 1,
  'frequency_RecentiorLatinitas': 0},
 'form_766441_v': {'orth_form': 'stringentem',
  'phon_form': 's t r i n ɡ ˈe n t e m',
  'frequency': 6,
  'frequency_Antiquitas': 2,
  'frequency_AetasPatrum': 3,
  'frequency_MediumAeuum': 1,
  'frequency_RecentiorLatinitas': 0},
 'form_766442_v': {'orth_form': 'stringēns',
  'phon_form': 's t r ˈi n ɡ eː n s',
  'frequency': 45,
  'frequency_Antiquitas': 2,
  'frequency_AetasPatrum': 14,
  'frequency_MediumAeuum': 26,
  'frequency_RecentiorLatinitas': 3},
 'form_766443_v': {'orth_form': 'stringēns',
  'phon_form': 's t r ˈi n ɡ eː n s',
  'frequency': 45,
  'frequency_Antiquitas': 2,
  'frequency_AetasPatrum': 14,
  'frequency_MediumAeuum': 26,
  'frequency_RecentiorLatinitas': 3},
 'form_766444_v': {'orth_form': 'stringēns',
  'phon_form': 's t r ˈi n ɡ eː n s',
  'frequency': 45,
  'frequency_Antiquitas': 2,
  'frequency_AetasPatrum': 14,
  'frequency_MediumAeuum': 26,
  'frequency_RecentiorLatinitas': 3},
 'form_766445_v': {'orth_form': 'stringēns',
  'phon_form': 's t r ˈi n ɡ eː n s',
  'frequency': 45,
  'frequency_Antiquitas': 2,
  'frequency_AetasPatrum': 14,
  'frequency_MediumAeuum': 26,
  'frequency_RecentiorLatinitas': 3},
 'form_766446_v': {'orth_form': 'stringente',
  'phon_form': 's t r i n ɡ ˈe n t e',
  'frequency': 8,
  'frequency_Antiquitas': 1,
  'frequency_AetasPatrum': 5,
  'frequency_MediumAeuum': 1,
  'frequency_RecentiorLatinitas': 1},
 'form_766447_v': {'orth_form': 'stringente',
  'phon_form': 's t r i n ɡ ˈe n t e',
  'frequency': 8,
  'frequency_Antiquitas': 1,
  'frequency_AetasPatrum': 5,
  'frequency_MediumAeuum': 1,
  'frequency_RecentiorLatinitas': 1},
 'form_766448_v': {'orth_form': 'stringente',
  'phon_form': 's t r i n ɡ ˈe n t e',
  'frequency': 8,
  'frequency_Antiquitas': 1,
  'frequency_AetasPatrum': 5,
  'frequency_MediumAeuum': 1,
  'frequency_RecentiorLatinitas': 1},
 'form_766449_v': {'orth_form': 'stringentēs',
  'phon_form': 's t r i n ɡ ˈe n t eː s',
  'frequency': 7,
  'frequency_Antiquitas': 0,
  'frequency_AetasPatrum': 4,
  'frequency_MediumAeuum': 3,
  'frequency_RecentiorLatinitas': 0},
 'form_766450_v': {'orth_form': 'stringentēs',
  'phon_form': 's t r i n ɡ ˈe n t eː s',
  'frequency': 7,
  'frequency_Antiquitas': 0,
  'frequency_AetasPatrum': 4,
  'frequency_MediumAeuum': 3,
  'frequency_RecentiorLatinitas': 0},
 'form_766451_v': {'orth_form': 'stringentia',
  'phon_form': 's t r i n ɡ ˈe n t i a',
  'frequency': 3,
  'frequency_Antiquitas': 1,
  'frequency_AetasPatrum': 1,
  'frequency_MediumAeuum': 1,
  'frequency_RecentiorLatinitas': 0},
 'form_766452_v': {'orth_form': 'stringentium',
  'phon_form': 's t r i n ɡ ˈe n t i u m',
  'frequency': 2,
  'frequency_Antiquitas': 1,
  'frequency_AetasPatrum': 0,
  'frequency_MediumAeuum': 1,
  'frequency_RecentiorLatinitas': 0},
 'form_766453_v': {'orth_form': 'stringentium',
  'phon_form': 's t r i n ɡ ˈe n t i u m',
  'frequency': 2,
  'frequency_Antiquitas': 1,
  'frequency_AetasPatrum': 0,
  'frequency_MediumAeuum': 1,
  'frequency_RecentiorLatinitas': 0},
 'form_766454_v': {'orth_form': 'stringentium',
  'phon_form': 's t r i n ɡ ˈe n t i u m',
  'frequency': 2,
  'frequency_Antiquitas': 1,
  'frequency_AetasPatrum': 0,
  'frequency_MediumAeuum': 1,
  'frequency_RecentiorLatinitas': 0},
 'form_766455_v': {'orth_form': 'stringentibus',
  'phon_form': 's t r i n ɡ ˈe n t i b u s',
  'frequency': 1,
  'frequency_Antiquitas': 0,
  'frequency_AetasPatrum': 1,
  'frequency_MediumAeuum': 0,
  'frequency_RecentiorLatinitas': 0},
 'form_766456_v': {'orth_form': 'stringentibus',
  'phon_form': 's t r i n ɡ ˈe n t i b u s',
  'frequency': 1,
  'frequency_Antiquitas': 0,
  'frequency_AetasPatrum': 1,
  'frequency_MediumAeuum': 0,
  'frequency_RecentiorLatinitas': 0},
 'form_766457_v': {'orth_form': 'stringentibus',
  'phon_form': 's t r i n ɡ ˈe n t i b u s',
  'frequency': 1,
  'frequency_Antiquitas': 0,
  'frequency_AetasPatrum': 1,
  'frequency_MediumAeuum': 0,
  'frequency_RecentiorLatinitas': 0},
 'form_766458_v': {'orth_form': 'stringentēs',
  'phon_form': 's t r i n ɡ ˈe n t eː s',
  'frequency': 7,
  'frequency_Antiquitas': 0,
  'frequency_AetasPatrum': 4,
  'frequency_MediumAeuum': 3,
  'frequency_RecentiorLatinitas': 0},
 'form_766459_v': {'orth_form': 'stringentēs',
  'phon_form': 's t r i n ɡ ˈe n t eː s',
  'frequency': 7,
  'frequency_Antiquitas': 0,
  'frequency_AetasPatrum': 4,
  'frequency_MediumAeuum': 3,
  'frequency_RecentiorLatinitas': 0},
 'form_766460_v': {'orth_form': 'stringentia',
  'phon_form': 's t r i n ɡ ˈe n t i a',
  'frequency': 3,
  'frequency_Antiquitas': 1,
  'frequency_AetasPatrum': 1,
  'frequency_MediumAeuum': 1,
  'frequency_RecentiorLatinitas': 0},
 'form_766461_v': {'orth_form': 'stringentēs',
  'phon_form': 's t r i n ɡ ˈe n t eː s',
  'frequency': 7,
  'frequency_Antiquitas': 0,
  'frequency_AetasPatrum': 4,
  'frequency_MediumAeuum': 3,
  'frequency_RecentiorLatinitas': 0},
 'form_766462_v': {'orth_form': 'stringentēs',
  'phon_form': 's t r i n ɡ ˈe n t eː s',
  'frequency': 7,
  'frequency_Antiquitas': 0,
  'frequency_AetasPatrum': 4,
  'frequency_MediumAeuum': 3,
  'frequency_RecentiorLatinitas': 0},
 'form_766463_v': {'orth_form': 'stringentia',
  'phon_form': 's t r i n ɡ ˈe n t i a',
  'frequency': 3,
  'frequency_Antiquitas': 1,
  'frequency_AetasPatrum': 1,
  'frequency_MediumAeuum': 1,
  'frequency_RecentiorLatinitas': 0},
 'form_766464_v': {'orth_form': 'stringentibus',
  'phon_form': 's t r i n ɡ ˈe n t i b u s',
  'frequency': 1,
  'frequency_Antiquitas': 0,
  'frequency_AetasPatrum': 1,
  'frequency_MediumAeuum': 0,
  'frequency_RecentiorLatinitas': 0},
 'form_766465_v': {'orth_form': 'stringentibus',
  'phon_form': 's t r i n ɡ ˈe n t i b u s',
  'frequency': 1,
  'frequency_Antiquitas': 0,
  'frequency_AetasPatrum': 1,
  'frequency_MediumAeuum': 0,
  'frequency_RecentiorLatinitas': 0},
 'form_766466_v': {'orth_form': 'stringentibus',
  'phon_form': 's t r i n ɡ ˈe n t i b u s',
  'frequency': 1,
  'frequency_Antiquitas': 0,
  'frequency_AetasPatrum': 1,
  'frequency_MediumAeuum': 0,
  'frequency_RecentiorLatinitas': 0},
 'form_634166_v': {'orth_form': 'praescrīptus',
  'phon_form': 'p r a j s k r ˈiː p t u s',
  'frequency': 52,
  'frequency_Antiquitas': 1,
  'frequency_AetasPatrum': 14,
  'frequency_MediumAeuum': 34,
  'frequency_RecentiorLatinitas': 3},
 'form_634167_v': {'orth_form': 'praescrīpta',
  'phon_form': 'p r a j s k r ˈiː p t a',
  'frequency': 194,
  'frequency_Antiquitas': 12,
  'frequency_AetasPatrum': 88,
  'frequency_MediumAeuum': 74,
  'frequency_RecentiorLatinitas': 20},
 'form_634168_v': {'orth_form': 'praescrīptum',
  'phon_form': 'p r a j s k r ˈiː p t u m',
  'frequency': 245,
  'frequency_Antiquitas': 34,
  'frequency_AetasPatrum': 113,
  'frequency_MediumAeuum': 71,
  'frequency_RecentiorLatinitas': 27},
 'form_634169_v': {'orth_form': 'praescrīptī',
  'phon_form': 'p r a j s k r ˈiː p t iː',
  'frequency': 39,
  'frequency_Antiquitas': 0,
  'frequency_AetasPatrum': 18,
  'frequency_MediumAeuum': 20,
  'frequency_RecentiorLatinitas': 1},
 'form_634170_v': {'orth_form': 'praescrīptae',
  'phon_form': 'p r a j s k r ˈiː p t a j',
  'frequency': 24,
  'frequency_Antiquitas': 0,
  'frequency_AetasPatrum': 9,
  'frequency_MediumAeuum': 10,
  'frequency_RecentiorLatinitas': 5},
 'form_634171_v': {'orth_form': 'praescrīptī',
  'phon_form': 'p r a j s k r ˈiː p t iː',
  'frequency': 39,
  'frequency_Antiquitas': 0,
  'frequency_AetasPatrum': 18,
  'frequency_MediumAeuum': 20,
  'frequency_RecentiorLatinitas': 1},
 'form_634172_v': {'orth_form': 'praescrīptō',
  'phon_form': 'p r a j s k r ˈiː p t oː',
  'frequency': 116,
  'frequency_Antiquitas': 10,
  'frequency_AetasPatrum': 44,
  'frequency_MediumAeuum': 35,
  'frequency_RecentiorLatinitas': 27},
 'form_634173_v': {'orth_form': 'praescrīptae',
  'phon_form': 'p r a j s k r ˈiː p t a j',
  'frequency': 24,
  'frequency_Antiquitas': 0,
  'frequency_AetasPatrum': 9,
  'frequency_MediumAeuum': 10,
  'frequency_RecentiorLatinitas': 5},
 'form_634174_v': {'orth_form': 'praescrīptō',
  'phon_form': 'p r a j s k r ˈiː p t oː',
  'frequency': 116,
  'frequency_Antiquitas': 10,
  'frequency_AetasPatrum': 44,
  'frequency_MediumAeuum': 35,
  'frequency_RecentiorLatinitas': 27},
 'form_634175_v': {'orth_form': 'praescrīptum',
  'phon_form': 'p r a j s k r ˈiː p t u m',
  'frequency': 245,
  'frequency_Antiquitas': 34,
  'frequency_AetasPatrum': 113,
  'frequency_MediumAeuum': 71,
  'frequency_RecentiorLatinitas': 27},
 'form_634176_v': {'orth_form': 'praescrīptam',
  'phon_form': 'p r a j s k r ˈiː p t a m',
  'frequency': 59,
  'frequency_Antiquitas': 1,
  'frequency_AetasPatrum': 14,
  'frequency_MediumAeuum': 37,
  'frequency_RecentiorLatinitas': 7},
 'form_634177_v': {'orth_form': 'praescrīptum',
  'phon_form': 'p r a j s k r ˈiː p t u m',
  'frequency': 245,
  'frequency_Antiquitas': 34,
  'frequency_AetasPatrum': 113,
  'frequency_MediumAeuum': 71,
  'frequency_RecentiorLatinitas': 27},
 'form_634178_v': {'orth_form': 'praescrīpte',
  'phon_form': 'p r a j s k r ˈiː p t e',
  'frequency': 1,
  'frequency_Antiquitas': 0,
  'frequency_AetasPatrum': 0,
  'frequency_MediumAeuum': 1,
  'frequency_RecentiorLatinitas': 0},
 'form_634179_v': {'orth_form': 'praescrīpta',
  'phon_form': 'p r a j s k r ˈiː p t a',
  'frequency': 194,
  'frequency_Antiquitas': 12,
  'frequency_AetasPatrum': 88,
  'frequency_MediumAeuum': 74,
  'frequency_RecentiorLatinitas': 20},
 'form_634180_v': {'orth_form': 'praescrīptum',
  'phon_form': 'p r a j s k r ˈiː p t u m',
  'frequency': 245,
  'frequency_Antiquitas': 34,
  'frequency_AetasPatrum': 113,
  'frequency_MediumAeuum': 71,
  'frequency_RecentiorLatinitas': 27},
 'form_634181_v': {'orth_form': 'praescrīptō',
  'phon_form': 'p r a j s k r ˈiː p t oː',
  'frequency': 116,
  'frequency_Antiquitas': 10,
  'frequency_AetasPatrum': 44,
  'frequency_MediumAeuum': 35,
  'frequency_RecentiorLatinitas': 27},
 'form_634182_v': {'orth_form': 'praescrīptā',
  'phon_form': 'p r a j s k r ˈiː p t aː',
  'frequency': 194,
  'frequency_Antiquitas': 12,
  'frequency_AetasPatrum': 88,
  'frequency_MediumAeuum': 74,
  'frequency_RecentiorLatinitas': 20},
 'form_634183_v': {'orth_form': 'praescrīptō',
  'phon_form': 'p r a j s k r ˈiː p t oː',
  'frequency': 116,
  'frequency_Antiquitas': 10,
  'frequency_AetasPatrum': 44,
  'frequency_MediumAeuum': 35,
  'frequency_RecentiorLatinitas': 27},
 'form_634184_v': {'orth_form': 'praescrīptī',
  'phon_form': 'p r a j s k r ˈiː p t iː',
  'frequency': 39,
  'frequency_Antiquitas': 0,
  'frequency_AetasPatrum': 18,
  'frequency_MediumAeuum': 20,
  'frequency_RecentiorLatinitas': 1},
 'form_634185_v': {'orth_form': 'praescrīptae',
  'phon_form': 'p r a j s k r ˈiː p t a j',
  'frequency': 24,
  'frequency_Antiquitas': 0,
  'frequency_AetasPatrum': 9,
  'frequency_MediumAeuum': 10,
  'frequency_RecentiorLatinitas': 5},
 'form_634186_v': {'orth_form': 'praescrīpta',
  'phon_form': 'p r a j s k r ˈiː p t a',
  'frequency': 194,
  'frequency_Antiquitas': 12,
  'frequency_AetasPatrum': 88,
  'frequency_MediumAeuum': 74,
  'frequency_RecentiorLatinitas': 20},
 'form_634187_v': {'orth_form': 'praescrīptōrum',
  'phon_form': 'p r a j s k r iː p t ˈoː r u m',
  'frequency': 11,
  'frequency_Antiquitas': 0,
  'frequency_AetasPatrum': 6,
  'frequency_MediumAeuum': 5,
  'frequency_RecentiorLatinitas': 0},
 'form_634188_v': {'orth_form': 'praescrīptārum',
  'phon_form': 'p r a j s k r iː p t ˈaː r u m',
  'frequency': 1,
  'frequency_Antiquitas': 0,
  'frequency_AetasPatrum': 0,
  'frequency_MediumAeuum': 1,
  'frequency_RecentiorLatinitas': 0},
 'form_634189_v': {'orth_form': 'praescrīptōrum',
  'phon_form': 'p r a j s k r iː p t ˈoː r u m',
  'frequency': 11,
  'frequency_Antiquitas': 0,
  'frequency_AetasPatrum': 6,
  'frequency_MediumAeuum': 5,
  'frequency_RecentiorLatinitas': 0},
 'form_634190_v': {'orth_form': 'praescrīptīs',
  'phon_form': 'p r a j s k r ˈiː p t iː s',
  'frequency': 93,
  'frequency_Antiquitas': 1,
  'frequency_AetasPatrum': 65,
  'frequency_MediumAeuum': 15,
  'frequency_RecentiorLatinitas': 12},
 'form_634191_v': {'orth_form': 'praescrīptīs',
  'phon_form': 'p r a j s k r ˈiː p t iː s',
  'frequency': 93,
  'frequency_Antiquitas': 1,
  'frequency_AetasPatrum': 65,
  'frequency_MediumAeuum': 15,
  'frequency_RecentiorLatinitas': 12},
 'form_634192_v': {'orth_form': 'praescrīptīs',
  'phon_form': 'p r a j s k r ˈiː p t iː s',
  'frequency': 93,
  'frequency_Antiquitas': 1,
  'frequency_AetasPatrum': 65,
  'frequency_MediumAeuum': 15,
  'frequency_RecentiorLatinitas': 12},
 'form_634193_v': {'orth_form': 'praescrīptōs',
  'phon_form': 'p r a j s k r ˈiː p t oː s',
  'frequency': 21,
  'frequency_Antiquitas': 2,
  'frequency_AetasPatrum': 14,
  'frequency_MediumAeuum': 5,
  'frequency_RecentiorLatinitas': 0},
 'form_634194_v': {'orth_form': 'praescrīptās',
  'phon_form': 'p r a j s k r ˈiː p t aː s',
  'frequency': 16,
  'frequency_Antiquitas': 1,
  'frequency_AetasPatrum': 5,
  'frequency_MediumAeuum': 7,
  'frequency_RecentiorLatinitas': 3},
 'form_634195_v': {'orth_form': 'praescrīpta',
  'phon_form': 'p r a j s k r ˈiː p t a',
  'frequency': 194,
  'frequency_Antiquitas': 12,
  'frequency_AetasPatrum': 88,
  'frequency_MediumAeuum': 74,
  'frequency_RecentiorLatinitas': 20},
 'form_634196_v': {'orth_form': 'praescrīptī',
  'phon_form': 'p r a j s k r ˈiː p t iː',
  'frequency': 39,
  'frequency_Antiquitas': 0,
  'frequency_AetasPatrum': 18,
  'frequency_MediumAeuum': 20,
  'frequency_RecentiorLatinitas': 1},
 'form_634197_v': {'orth_form': 'praescrīptae',
  'phon_form': 'p r a j s k r ˈiː p t a j',
  'frequency': 24,
  'frequency_Antiquitas': 0,
  'frequency_AetasPatrum': 9,
  'frequency_MediumAeuum': 10,
  'frequency_RecentiorLatinitas': 5},
 'form_634198_v': {'orth_form': 'praescrīpta',
  'phon_form': 'p r a j s k r ˈiː p t a',
  'frequency': 194,
  'frequency_Antiquitas': 12,
  'frequency_AetasPatrum': 88,
  'frequency_MediumAeuum': 74,
  'frequency_RecentiorLatinitas': 20},
 'form_634199_v': {'orth_form': 'praescrīptīs',
  'phon_form': 'p r a j s k r ˈiː p t iː s',
  'frequency': 93,
  'frequency_Antiquitas': 1,
  'frequency_AetasPatrum': 65,
  'frequency_MediumAeuum': 15,
  'frequency_RecentiorLatinitas': 12},
 'form_634200_v': {'orth_form': 'praescrīptīs',
  'phon_form': 'p r a j s k r ˈiː p t iː s',
  'frequency': 93,
  'frequency_Antiquitas': 1,
  'frequency_AetasPatrum': 65,
  'frequency_MediumAeuum': 15,
  'frequency_RecentiorLatinitas': 12},
 'form_634201_v': {'orth_form': 'praescrīptīs',
  'phon_form': 'p r a j s k r ˈiː p t iː s',
  'frequency': 93,
  'frequency_Antiquitas': 1,
  'frequency_AetasPatrum': 65,
  'frequency_MediumAeuum': 15,
  'frequency_RecentiorLatinitas': 12}}

# %%
for row in changes_forms:
    print(row)
    for column in changes_forms[row]:
        print(column)
        print(changes_forms[row][column])
        LatInfLexi_forms.loc[row,column] = changes_forms[row][column]
# Out:
# form_766318_v
# orth_form
# stringō
# phon_form
# s t r ˈi n ɡ oː
# frequency
# 11
# frequency_Antiquitas
# 0
# frequency_AetasPatrum
# 4
# frequency_MediumAeuum
# 7
# frequency_RecentiorLatinitas
# 0
# form_766319_v
# orth_form
# stringis
# phon_form
# s t r ˈi n ɡ i s
# frequency
# 13
# frequency_Antiquitas
# 3
# frequency_AetasPatrum
# 4
# frequency_MediumAeuum
# 6
# frequency_RecentiorLatinitas
# 0
# form_766320_v
# orth_form
# stringit
# phon_form
# s t r ˈi n ɡ i t
# frequency
# 192
# frequency_Antiquitas
# 25
# frequency_AetasPatrum
# 63
# frequency_MediumAeuum
# 99
# frequency_RecentiorLatinitas
# 5
# form_766321_v
# orth_form
# stringimus
# phon_form
# s t r ˈi n ɡ i m u s
# frequency
# 6
# frequency_Antiquitas
# 1
# frequency_AetasPatrum
# 3
# frequency_MediumAeuum
# 2
# frequency_RecentiorLatinitas
# 0
# form_766322_v
# orth_form
# stringitis
# phon_form
# s t r ˈi n ɡ i t i s
# frequency
# 3
# frequency_Antiquitas
# 0
# frequency_AetasPatrum
# 3
# frequency_MediumAeuum
# ...

# %% [markdown]
# # Changes to lexemes

# %%
changes_lexemes = {'stringo_v': {
  'frequency': 4621,
  'frequency_Antiquitas':1052,
  'frequency_AetasPatrum': 1370,
  'frequency_MediumAeuum': 1989,
  'frequency_RecentiorLatinitas': 210},
                   'praescribo_v': {
  'frequency': 5460,
  'frequency_Antiquitas':430,
  'frequency_AetasPatrum': 2604,
  'frequency_MediumAeuum': 1791,
  'frequency_RecentiorLatinitas': 635}
                  }

# %%
for row in changes_lexemes:
    #print(row)
    for column in changes_lexemes[row]:
        #print(column)
        #print(changes_lexemes[row][column])
        LatInfLexi_lexemes.loc[row,column] = changes_lexemes[row][column]

# %% [markdown]
# # Updating cell frequencies

# %%
cells_freq = LatInfLexi_forms.groupby("cell")[["frequency", 
                                              "frequency_Antiquitas",
                                              "frequency_AetasPatrum",
                                              "frequency_MediumAeuum",
                                              "frequency_RecentiorLatinitas"]].agg(sum)
cells_freq.index.name = "cell_id"
# Out:
# C:\Users\matteo.pellegrini\AppData\Local\Temp\ipykernel_6168\418782974.py:5: FutureWarning: The provided callable <built-in function sum> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   "frequency_RecentiorLatinitas"]].agg(sum)

# %%
LatInfLexi_cells = LatInfLexi_cells.drop(columns = ["frequency", 
                                              "frequency_Antiquitas",
                                              "frequency_AetasPatrum",
                                              "frequency_MediumAeuum",
                                              "frequency_RecentiorLatinitas"])

# %%
LatInfLexi_cells = pd.merge(LatInfLexi_cells, cells_freq, left_index=True, right_index=True)

# %% [markdown]
# # Writing to file

# %%
LatInfLexi_forms.to_csv("../LatInfLexi-forms.csv")
LatInfLexi_lexemes.to_csv("../LatInfLexi-lexemes.csv")
LatInfLexi_cells.to_csv("../LatInfLexi-cells.csv")
